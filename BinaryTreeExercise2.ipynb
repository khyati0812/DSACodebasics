# %% [markdown]
# <a href="https://colab.research.google.com/github/khyati0812/DSACodebasics/blob/main/BinaryTreeExercise2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class BinarySearchTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

    def add_child(self, data):
        if data == self.data:
            return # node already exist

        if data < self.data:
            if self.left:
                self.left.add_child(data)
            else:
                self.left = BinarySearchTreeNode(data)
        else:
            if self.right:
                self.right.add_child(data)
            else:
                self.right = BinarySearchTreeNode(data)


    def search(self, val):
        if self.data == val:
            return True

        if val < self.data:
            if self.left:
                return self.left.search(val)
            else:
                return False

        if val > self.data:
            if self.right:
                return self.right.search(val)
            else:
                return False
    def find_min(self):
      if self is None:
        return None
      node=self
      while node.left:
        node=node.left
      return node.data
    def find_max(self):
      if self is None:
        return None
      node=self
      while node.right:
        node=node.right
      return node.data
    def delete_node(self, val):
     if val < self.data:
        if self.left:
            self.left = self.left.delete_node(val)
     elif val > self.data:
        if self.right:
            self.right = self.right.delete_node(val)
     else:
        # Case 1: Node to be deleted has no children (it's a leaf node)
        if self.left is None and self.right is None:
            return None
        # Case 2: Node to be deleted has one child
        elif self.left is None:
            return self.right
        elif self.right is None:
            return self.left
        # Case 3: Node to be deleted has two children
        else:
            max_val = self.left.find_max()
            self.data = max_val
            self.left = self.left.delete_node(max_val)
     return self



    def in_order_traversal(self):
        elements = []
        if self.left:
            elements += self.left.in_order_traversal()

        elements.append(self.data)

        if self.right:
            elements += self.right.in_order_traversal()

        return elements
    def pre_order_traversal(self,pre):
        if self is None:
          return
        pre.append(self.data)
        if self.left:

         self.left.pre_order_traversal(pre)
        if self.right:
         self.right.pre_order_traversal(pre)

    def post_order_traversal(self,post,sum):
        if self is None:
          return

        if self.left:

         self.left.post_order_traversal(post,sum)
        if self.right:
         self.right.post_order_traversal(post,sum)
        sum+=self.data
        post.append(self.data)

def build_tree(elements):
    print("Building tree with these elements:",elements)
    root = BinarySearchTreeNode(elements[0])

    for i in range(1,len(elements)):
        root.add_child(elements[i])

    return root

if __name__ == '__main__':
    countries = ["India","Pakistan","Germany", "USA","China","India","UK","USA"]
    country_tree = build_tree(countries)

    print("UK is in the list? ", country_tree.search("UK"))
    print("Sweden is in the list? ", country_tree.search("Sweden"))

    numbers_tree = build_tree([1,2,3,4,5,11,13,23,12,28])
    print("In order traversal gives this sorted list:",numbers_tree.in_order_traversal())
    pre=[]
    post=[]
    print("Minimum value", numbers_tree.find_min())
    print("Maximum value", numbers_tree.find_max())
    print("Preorder traversal",numbers_tree.pre_order_traversal(pre))
    sum=0

    numbers_tree.post_order_traversal(post,sum)

    for i in pre:
      print(i)
    print()
    for i in post:
      sum+=i
      print(i)
    print()
    print(sum)
    numbers_tree.delete_node(12)
    pre=[]
    print("Preorder traversal",numbers_tree.pre_order_traversal(pre))
    for i in pre:
      print(i,end=" ")
# Out:
# Building tree with these elements: ['India', 'Pakistan', 'Germany', 'USA', 'China', 'India', 'UK', 'USA']
# UK is in the list?  True
# Sweden is in the list?  False
# Building tree with these elements: [1, 2, 3, 4, 5, 11, 13, 23, 12, 28]
# In order traversal gives this sorted list: [1, 2, 3, 4, 5, 11, 12, 13, 23, 28]
# Minimum value 1
# Maximum value 28
# Preorder traversal None
# 1
# 2
# 3
# 4
# 5
# 11
# 13
# 12
# 23
# 28
#
# 12
# 28
# 23
# 13
# 11
# 5
# 4
# 3
# 2
# 1
#
# 102
# Preorder traversal None
# 1 2 3 4 5 11 13 23 28

# %%
numbers_tree.delete_node(12)
pre=[]
print("Preorder traversal",numbers_tree.pre_order_traversal(pre))
for i in pre:
      print(i)
# Out:
# Preorder traversal None
# 1
# 2
# 4
# 5
# 11
# 13
# 23
