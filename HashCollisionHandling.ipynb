# %% [markdown]
# <a href="https://colab.research.google.com/github/khyati0812/DSACodebasics/blob/main/HashCollisionHandling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dict={}
maxi=0
with open("/content/nyc_weather (1).csv","r") as f:
  for line in f:
    lines=line.split(",")
    date=lines[0]
    temperature=lines[1]
    if(date=="date"):
     continue
    print(date," ",temperature)
    if (int(temperature)>maxi):
      maxi=int(temperature)

    dict[date]=temperature
sum=0
for key,value in dict.items():
    st=key.split(" ")
    if(int(st[1])<=7):
     sum+=int(value)
    if(int(st[1])==9) :
      print("Temperature on Jan 9=",value)
    if(int(st[1])==4) :
      print("Temperature on Jan 4=",value)
print(sum/7)
print(maxi)
# Out:
# Jan 1   27
#
# Jan 2   31
#
# Jan 3   23
#
# Jan 4   34
#
# Jan 5   37
#
# Jan 6   38
#
# Jan 7   29
#
# Jan 8   30
#
# Jan 9   35
#
# Jan 10   30
# Temperature on Jan 4= 34
#
# Temperature on Jan 9= 35
#
# 31.285714285714285
# 38

# %%
with open("/content/poem (1).txt","r") as f:
   dict={}
   for line in f:
    lines=line.split(",")
    #print(lines[0])
    ' '.join(e for e in lines[0] if e.isalnum())
    normal_string=''.join(filter(str.isalnum, lines[0]))
    print("String after conversion: ",normal_string)
    print(lines[0])
    # print(type(lines[0]))
    #line1=lines[0].split(" ")
    # print(line1)
    # for x in line1:
    #   print(x,end=" ")
    #   if x in dict.keys():
    #     dict[x]+=1
    #   else:
    #     dict[x]=1
    # print()
dict
# Out:
# String after conversion:  Tworoadsdivergedinayellowwood
# Two roads diverged in a yellow wood
# String after conversion:  AndsorryIcouldnottravelboth
# And sorry I could not travel both
#
# String after conversion:  Andbeonetraveler
# And be one traveler
# String after conversion:  AndlookeddownoneasfarasIcould
# And looked down one as far as I could
#
# String after conversion:  Towhereitbentintheundergrowth
# To where it bent in the undergrowth;
#
# String after conversion:
#
#
# String after conversion:  Thentooktheother
# Then took the other
# String after conversion:  Andhavingperhapsthebetterclaim
# And having perhaps the better claim
# String after conversion:  Becauseitwasgrassyandwantedwear
# Because it was grassy and wanted wear;
#
# String after conversion:  Thoughasforthatthepassingthere
# Though as for that the passing there
#
# String after conversion:  Hadwornthemreallyaboutthesame
# Had worn them really about the same
# String after conversion:
#
#
# ...

# %%
from collections import defaultdict
import string
with open("/content/poem (1).txt","r") as f:
   dict={}
   for line in f:
    line.translate(str.maketrans('', '', string.punctuation))
    words=line.split()
    print(words)
# Out:
# ['Two', 'roads', 'diverged', 'in', 'a', 'yellow', 'wood,']
# ['And', 'sorry', 'I', 'could', 'not', 'travel', 'both']
# ['And', 'be', 'one', 'traveler,', 'long', 'I', 'stood']
# ['And', 'looked', 'down', 'one', 'as', 'far', 'as', 'I', 'could']
# ['To', 'where', 'it', 'bent', 'in', 'the', 'undergrowth;']
# []
# ['Then', 'took', 'the', 'other,', 'as', 'just', 'as', 'fair,']
# ['And', 'having', 'perhaps', 'the', 'better', 'claim,']
# ['Because', 'it', 'was', 'grassy', 'and', 'wanted', 'wear;']
# ['Though', 'as', 'for', 'that', 'the', 'passing', 'there']
# ['Had', 'worn', 'them', 'really', 'about', 'the', 'same,']
# []
# ['And', 'both', 'that', 'morning', 'equally', 'lay']
# ['In', 'leaves', 'no', 'step', 'had', 'trodden', 'black.']
# ['Oh,', 'I', 'kept', 'the', 'first', 'for', 'another', 'day!']
# ['Yet', 'knowing', 'how', 'way', 'leads', 'on', 'to', 'way,']
# ['I', 'doubted', 'if', 'I', 'should', 'ever', 'come', 'back.']
# []
# ...

# %%
word_count = {}
with open("/content/poem (1).txt","r") as f:
    for line in f:
        tokens = line.split(' ')
        # print(tokens)
        for token in tokens:
            print(token)
            token=token.replace('\n','')
            print(token)
            if token in word_count:
                word_count[token]+=1
            else:
                word_count[token]=1
word_count
# Out:
# Two
# Two
# roads
# roads
# diverged
# diverged
# in
# in
# a
# a
# yellow
# yellow
# wood,
#
# wood,
# And
# And
# sorry
# sorry
# I
# I
# could
# could
# not
# not
# travel
# travel
# both
#
# both
# And
# And
# be
# be
# one
# one
# traveler,
# traveler,
# long
# long
# I
# I
# stood
#
# stood
# And
# And
# looked
# looked
# down
# down
# one
# one
# as
# as
# far
# far
# as
# as
# I
# I
# could
#
# could
# To
# To
# where
# where
# it
# it
# bent
# bent
# in
# in
# the
# the
# undergrowth;
#
# undergrowth;
#
#
#
# Then
# Then
# took
# took
# the
# the
# other,
# other,
# as
# as
# just
# just
# as
# as
# fair,
#
# fair,
# And
# And
# having
# having
# perhaps
# perhaps
# the
# the
# better
# better
# claim,
#
# claim,
# Because
# Because
# it
# it
# was
# was
# grassy
# grassy
# and
# and
# wanted
# wanted
# wear;
#
# wear;
# Though
# Though
# as
# as
# for
# for
# that
# that
# the
# the
# passing
# passing
# there
#
# there
# Had
# Had
# worn
# worn
# them
# them
# really
# ...

# %%
f=open("/content/poem (1).txt","r")
f.readline()
# Out:
# 'Two roads diverged in a yellow wood,\n'

# %%
f = open('/content/poem (1).txt')
line = f.readline()   # include newline
dict={}
while line:
        line = line.rstrip()  # strip trailing spaces and newline
        # process the line
        #print(line)
        lines=line.split("\n")
        # print(lines)

        print(lines)

        line = f.readline()

dict
# Out:
# ['Two roads diverged in a yellow wood,']
# ['And sorry I could not travel both']
# ['And be one traveler, long I stood']
# ['And looked down one as far as I could']
# ['To where it bent in the undergrowth;']
# ['']
# ['Then took the other, as just as fair,']
# ['And having perhaps the better claim,']
# ['Because it was grassy and wanted wear;']
# ['Though as for that the passing there']
# ['Had worn them really about the same,']
# ['']
# ['And both that morning equally lay']
# ['In leaves no step had trodden black.']
# ['Oh, I kept the first for another day!']
# ['Yet knowing how way leads on to way,']
# ['I doubted if I should ever come back.']
# ['']
# ['I shall be telling this with a sigh']
# ['Somewhere ages and ages hence:']
# ['Two roads diverged in a wood, and I—']
# ['I took the one less traveled by,']
# ['And that has made all the difference.']
# {}

# %%
class HashTable:
    def __init__(self):
        self.MAX = 10
        self.arr = [None for i in range(self.MAX)]

    def get_hash(self, key):
        hash = 0
        for char in key:
            hash += ord(char)
        return hash % self.MAX

    def __getitem__(self, index):
        h = self.get_hash(index)
        return self.arr[h]

    def __setitem__(self, key, val):
        h = self.get_hash(key)
        if self.arr[h] is not None:
          while self.arr[h] is not None:
            h+=1
            h=h%self.MAX
        self.arr[h] = val

# %%
t = HashTable()
t.get_hash("march 6")
# Out:
# 9

# %%
t.get_hash("march 17")
# Out:
# 9

# %%
t["march 6"] = 120
t["march 8"] = 67
t["march 9"] = 4
t["march 17"] = 459

# %%
t["march 6"]
# Out:
# 120
